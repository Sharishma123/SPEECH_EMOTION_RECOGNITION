# %%
pip install librosa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk("C:/Users/rajan/Downloads/archive (1)"):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['C:/Users/rajan/Downloads/archive (1)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'C:/Users/rajan/Downloads/archive (1)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'C:/Users/rajan/Downloads/archive (1)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'C:/Users/rajan/Downloads/archive (1)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'C:/Users/rajan/Downloads/archive (1)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  C:/Users/rajan/Downloads/archive (1)\TESS Toro...  angry
# 1  C:/Users/rajan/Downloads/archive (1)\TESS Toro...  angry
# 2  C:/Users/rajan/Downloads/archive (1)\TESS Toro...  angry
# 3  C:/Users/rajan/Downloads/archive (1)\TESS Toro...  angry
# 4  C:/Users/rajan/Downloads/archive (1)\TESS Toro...  angry

# %%
df['label'].value_counts()
# Out:
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: label, dtype: int64

# %%
#Exploratory Data Analysis
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveplot(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)

# Create a waveform plot using matplotlib
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)
plt.title(f'{emotion} Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Create a spectrogram (you might have a custom function for this)
spectogram(data, sampling_rate, emotion)

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Feature Extraction
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275506e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228361e+00, -5.57365894e-01, -1.83255327e+00,  2.02101514e-01,
#         7.27551103e-01,  1.31773770e+00,  2.88633752e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651056e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722402e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390714e+00,
#         4.86896276e+00,  9.31392384e+00,  2.08915019e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600896, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550478, -0.21709539, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.14.0-cp310-cp310-win_amd64.whl (2.1 kB)
# ...
#      ------------------------------------ 284.1/284.1 MB 446.5 kB/s eta 0:00:00
# ...
#      -------------------------------------- 57.5/57.5 kB 216.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 24.4/24.4 MB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.5/5.5 MB 2.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 938.6/938.6 kB 3.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 440.7/440.7 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 kB 3.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 130.2/130.2 kB 3.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 430.5/430.5 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.3/4.3 MB 2.2 MB/s eta 0:00:00
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# ...
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 9s 177ms/step - loss: 1.0871 - accuracy: 0.6076 - val_loss: 0.7758 - val_accuracy: 0.6768
# Epoch 2/50
# 35/35 [==============================] - 5s 156ms/step - loss: 0.3551 - accuracy: 0.8759 - val_loss: 0.0820 - val_accuracy: 0.9768
# Epoch 3/50
# 35/35 [==============================] - 5s 156ms/step - loss: 0.1992 - accuracy: 0.9406 - val_loss: 0.1868 - val_accuracy: 0.9214
# Epoch 4/50
# 35/35 [==============================] - 6s 170ms/step - loss: 0.1387 - accuracy: 0.9571 - val_loss: 0.1853 - val_accuracy: 0.9339
# Epoch 5/50
# 35/35 [==============================] - 5s 153ms/step - loss: 0.1040 - accuracy: 0.9710 - val_loss: 0.0207 - val_accuracy: 0.9946
# Epoch 6/50
# 35/35 [==============================] - 5s 155ms/step - loss: 0.1216 - accuracy: 0.9647 - val_loss: 0.1095 - val_accuracy: 0.9696
# Epoch 7/50
# ...

# %%
#Plot the results
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
